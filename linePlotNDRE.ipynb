# %%
import matplotlib.pyplot as plt

# %%
campo3Acc = [0.7036029911624745,0.5513256288239293,0.43847722637661457,0.37049626104690686,0.3263086335825969]
campo3Prec = [0.7228084875568724,0.5647480839352904,0.4835347065011091,0.33539890747162215,0.247909458684591]
campo3Recall = [0.7035030316474415,0.5513418401984013,0.4384366485013624,0.3702794164463958,0.3261185775123057]

# %%
campo4Acc = [0.752112676056338,0.5549295774647888,0.4291079812206573,0.3530516431924883,0.29859154929577464]
campo4Prec = [0.7680995475113122,0.38265685148916057,0.22177573670110984,0.1467188942166993,0.1037684878773553]
campo4Recall = [0.7519978416961729,0.5549295774647888,0.4277227583885086,0.3530516431924883,0.29775280898876405]

# %%
campo6Acc = [0.7747058823529411,0.5923529411764706,0.4611764705882353,0.3688235294117647,0.3064705882352941]
campo6Prec = [0.8328448848873043,0.4548076083818424,0.2694825467802687,0.17281809575603763,0.11940690161428574]
campo6Recall = [0.7744598954462221,0.5920047031158142,0.45942001099505225,0.36823874417802316,0.3057511737089202]

# %%
fig, ax = plt.subplots()
plt.plot(range(2,7),campo3Acc,label="accuracy")
plt.plot(range(2,7),campo3Prec,label="precision")
plt.plot(range(2,7),campo3Recall,label="recall")
plt.legend()
ax.set_xticks(range(2,7))
plt.title("Metriche in funzione al numero di classe del campo 3")
ax.set_xlabel("numero di classe")
ax.set_ylabel("valore delle metriche")
print()

# %%
fig, ax = plt.subplots()
plt.plot(range(2,7),campo4Acc,label="accuracy")
plt.plot(range(2,7),campo4Prec,label="precision")
plt.plot(range(2,7),campo4Recall,label="recall")
plt.legend()
ax.set_xticks(range(2,7))
plt.title("Metriche in funzione al numero di classe del campo 4")
ax.set_xlabel("numero di classe")
ax.set_ylabel("valore delle metriche")
# Out:
# Text(0, 0.5, 'valore delle metriche')

# %%
fig, ax = plt.subplots()
plt.plot(range(2,7),campo6Acc,label="accuracy")
plt.plot(range(2,7),campo6Prec,label="precision")
plt.plot(range(2,7),campo6Recall,label="recall")
plt.legend()
ax.set_xticks(range(2,7))
plt.title("Metriche in funzione al numero di classe del campo 6")
ax.set_xlabel("numero di classe")
ax.set_ylabel("valore delle metriche")
# Out:
# Text(0, 0.5, 'valore delle metriche')
